# %% [markdown]
# # Pre-employment coursework
# ## Exercise 3 - Variational Autoencoder
#
# - **Model:** A Variational Autoencoder
# - **Aim:** Model should be trained to generate new instances of the training data.
# - **Sources:** Doerch, (2016), *Tutorial on Variational Autoencoders*, https://arxiv.org/pdf/1606.05908.pdf

# %%
# Imports
from collections import OrderedDict

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
torch.set_printoptions(linewidth=120)

import torchvision
from torchvision.transforms import transforms

from utils import *

print(torch.__version__)
print(torchvision.__version__)

# %% [markdown]
# ## Load the MNIST dataset

# %%
# Define transform (binarise images for higher precision)
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Lambda(lambda img: torch.round(img))])

MNIST_set = torchvision.datasets.MNIST(root='../data', train=True,
                                       download=True, transform=transform)

test_set = torchvision.datasets.MNIST(root='../data', train=False,
                                      download=True, transform=transform)

train_set, val_set = train_val_split(MNIST_set, 0.1)

# %% [markdown]
# ## Define model

# %%
class Encoder(nn.Module):
    """
    Simple CNN and fully connected encoder model.
    """
    
    def __init__(self, latent_dim):
        super(Encoder, self).__init__()
        self.encoder_layers = nn.Sequential(
            nn.Conv2d(1, 32, 3, 2, 1), # 32 14 14
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 64, 3, 2, 1), # 64 7 7
            nn.BatchNorm2d(64),
            nn.ReLU())
        self.linear = nn.Linear(64 * 7 * 7, latent_dim * 2)
    
    def forward(self, inputs):
        layered = self.encoder_layers(inputs)
        reshaped = layered.view(-1, 64 * 7 * 7)
        encoded = self.linear(reshaped)
        return encoded

# %%
class Decoder(nn.Module):
    """
    Simple CNN and fully connected decoder model.
    """
    
    def __init__(self, latent_dim):
        super(Decoder, self).__init__()
        self.linear = nn.Linear(latent_dim, 7 * 7 * 12)
        self.decoder_layers = nn.Sequential(
            nn.BatchNorm2d(12),
            nn.ReLU(),
            nn.ConvTranspose2d(12, 24, 3, 2, 0), # 64 15 15
            nn.BatchNorm2d(24),
            nn.ReLU(),
            nn.ConvTranspose2d(24, 36, 2, 2, 1), # ? 28 28
            nn.BatchNorm2d(36),
            nn.ConvTranspose2d(36, 1, 3, 1, 1))
        
    def forward(self, inputs):
        linear = self.linear(inputs)
        reshaped = linear.view(-1, 12, 7, 7)
        decoded = self.decoder_layers(reshaped)
        return decoded

# %%
class Autoencoder(nn.Module):
    """
    Autoencoder class, combines encoder and decoder models.
    """
    
    def __init__(self, latent_dim):
        super(Autoencoder, self).__init__()
        self.latent_dim = latent_dim
        self.encoder = Encoder(self.latent_dim)
        self.decoder = Decoder(self.latent_dim)
    
    @property
    def num_params(self):
        model_parameters = filter(lambda p: p.requires_grad, self.parameters())
        num_p = sum([np.prod(p.size()) for p in model_parameters])
        return num_p
    
    def inference(self, inputs):
        """
        Inference model. Encoded inputs return Gaussian parameters for
        modelling the latent space. The conditional latent distribution
        q(z|x) is then modelled with these parameters by sampling with
        the reparameterisation trick.
        """
        
        q_z_cond_x_params = self.encoder(inputs)
        q_z_cond_x_mu, q_z_cond_x_sigma_arg = torch.chunk(q_z_cond_x_params, chunks=2, dim=1)
        q_z_cond_x_sigma = self._softplus(q_z_cond_x_sigma_arg)
        z = self.sample(q_z_cond_x_mu, q_z_cond_x_sigma)
        log_q_z_cond_x = self._normallogprob(q_z_cond_x_mu, q_z_cond_x_sigma, z).sum(dim=1)
        return z, log_q_z_cond_x
    
    def generative(self, z, inputs):
        """
        Generative model. Computes the joint log-distribution
        
            log[p(x,z)] = log[p(x|z)] + log[p(z)]
        
        by computing the two components on the right-hand side which are
        the conditional distribution of the generated images and the prior
        distribution of the latent variables. The former is simply a binary
        cross-entropy loss between generated and real images, and the prior
        is modelled as a unit Gaussian.
        """
        
        p_z_mu = torch.zeros(z.shape)
        p_z_sigma = torch.ones(z.shape)
        log_p_z = self._normallogprob(p_z_mu, p_z_sigma, z).sum(dim=1)
        logits = self.decoder(z)
        log_p_x_cond_z = self._bernoullilogprob(logits, inputs).sum(dim=(1, 2, 3))
        log_p_x_and_z = log_p_x_cond_z + log_p_z
        return log_p_x_and_z
    
    def sample(self, mu, sigma):
        """
        Sampling from latent distribution, using the reparametrisation trick.
        """
        
        eps = torch.randn(sigma.shape)
        z = mu + sigma * eps
        return z
    
    def forward(self, inputs):
        """
        Forward pass of model. Returns ELBO of the batch.
        """
        
        z, log_q_z_cond_x = self.inference(inputs)
        log_p_x_and_z = self.generative(z, inputs)
        elbo = (log_p_x_and_z - log_q_z_cond_x).sum(dim=0)
        return elbo
    
    def _normallogprob(self, mu, sigma, z):
        var = torch.pow(sigma, 2)
        return -0.5 * torch.log(2 * np.pi * var) - torch.pow(z - mu, 2) / (2 * var)
    
    def _bernoullilogprob(self, logits, inputs):
        # bernoulli log prob is equivalent to negative binary cross entropy
        return -nn.BCEWithLogitsLoss(reduction='none')(logits, inputs)
    
    def _softplus(self, scale):
        return nn.Softplus()(scale)

# %%
latent_dim = 128
print("Number of parameters in model with latent_dim={0}: {1}"
      .format(latent_dim, Autoencoder(latent_dim).num_params))
# Out:
# Number of parameters in model with latent_dim=128: 904509

# %% [markdown]
# ## Training

# %%
param_names = ('init_lr', 'batch_size', 'latent_dim')
parameters = OrderedDict(
    run = [0.001, 128, 64]
)

# %%
m = RunManager()
num_epochs = 150
num_samples = 20

for hparams in RunBuilder.get_runs_from_params(param_names, parameters):

    # Instantiate a network model
    ae = Autoencoder(hparams.latent_dim)

    # Construct a DataLoader object with training data
    train_loader = DataLoader(train_set, batch_size=hparams.batch_size, shuffle=True)
    val_loader = DataLoader(val_set, batch_size=hparams.batch_size, shuffle=True)
    test_loader = DataLoader(test_set, batch_size=num_samples)
    test_images, _ = next(iter(test_loader))
    
    # Define random samples from standard Normal distribution for image generation
    sample_dim = (num_samples, hparams.latent_dim)
    test_latents = ae.sample(torch.zeros(sample_dim), torch.ones(sample_dim))
    
    # Define optimizer
    optimizer = optim.RMSprop(ae.parameters(), lr=hparams.init_lr, centered=True)
    scheduler = optim.lr_scheduler.StepLR(optimizer, 60, 0.1)
    
    # Setup run instance
    m.begin_run(hparams, ae, test_images, test_latents)
    m.generate_images()
    print('Now training model with hyperparameters: init_lr={0}, batch_size={1}, latent_dim={2}'
         .format(hparams.init_lr, hparams.batch_size, hparams.latent_dim))
    
    # Start training loop
    for epoch in range(num_epochs):
        m.begin_epoch()
        
        # Train the model
        for i, batch in enumerate(train_loader):
            optimizer.zero_grad()
            images, _ = batch

            # Calculating the loss
            elbo = ae(images)
            loss = -elbo
            
            if i % 10 == 0:
                with torch.no_grad():
                    val_images, _ = next(iter(val_loader))
                    val_elbo = ae(val_images)
                    val_loss = -val_elbo
                    m.track_loss(val_loss, val_images.size(0), mode='val')
                print('Epoch {0}, iteration {1}: train loss {2}, val loss {3}'.format(epoch+1,
                                                                               i*hparams.batch_size,
                                                                               round(loss.item() / hparams.batch_size, 6),
                                                                               round(val_loss.item() / hparams.batch_size, 6)))
            
            # Zero all gradients and backpropagate
            loss.backward()

            # Update the weights
            optimizer.step()
            
            m.track_loss(loss, images.size(0), mode='train')
            
        m.end_epoch()
    
    #torch.save(ae, './models/test_' + str(hparams) + '.pth')
    m.end_run()
    print("Model has finished training.\n")
    scheduler.step()
    
m.save('results_final')
print("Training completed.")
# Out:
# /Users/janxu/anaconda3/envs/deeprender/lib/python3.7/site-packages/torch/jit/__init__.py:1007: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Not within tolerance rtol=1e-05 atol=1e-05 at input[] (-11435.54296875 vs. -11386.46875) and 0 other locations (100.00%)
#   check_tolerance, _force_outplace, True, _module_class)
# Now training model with hyperparameters: init_lr=0.001, batch_size=512, latent_dim=512
# Epoch 1, iteration 0: train loss 1240.953613, val loss 1242.589722
# Epoch 1, iteration 5120: train loss 423.112885, val loss 423.476471
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-83a784d7c486> in <module>
#      53
#      54             # Zero all gradients and backpropagate
# ---> 55             loss.backward()
#      56
#      57             # Update the weights
#
# ~/anaconda3/envs/deeprender/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# ~/anaconda3/envs/deeprender/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
ae_best = torch.load('./models/Run(init_lr=0.0005, batch_size=128, latent_dim=256).pth')

# %%
num_samples = 20

print("Generating images...\n")
sample_dim = (num_samples, ae_best.latent_dim)
z_samples = ae_best.sample(torch.zeros(sample_dim), torch.ones(sample_dim))
with torch.no_grad():
    generated_imgs = nn.Sigmoid()(ae_best.decoder(z_samples))
    imgviz(generated_imgs)

# Test loss
test_loader = DataLoader(test_set, batch_size=len(test_set))
for i, batch in enumerate(test_loader):
    images, _ = batch
    with torch.no_grad():
        images, _ = next(iter(test_loader))
        elbo = ae(images)
        loss = -elbo
print('Test loss:', loss.item() / len(test_set))

# %%
zs = np.linspace(-3, 3, 10)
for j in range(ae_best.latent_dim):
    latents = torch.zeros((10, ae_best.latent_dim))
    for i in range(10):
        latents[i,j] = zs[i]
    print("Latent dimension index:", j)
    with torch.no_grad():
        generated_imgs = nn.Sigmoid()(ae_best.decoder(latents))
        imgviz(generated_imgs)
# Out:
# Latent dimension index: 0
# Latent dimension index: 1
# Latent dimension index: 2
# Latent dimension index: 3
# Latent dimension index: 4
# Latent dimension index: 5
# Latent dimension index: 6
# Latent dimension index: 7
# Latent dimension index: 8
# Latent dimension index: 9
# Latent dimension index: 10
# Latent dimension index: 11
# Latent dimension index: 12
# Latent dimension index: 13
# Latent dimension index: 14
# Latent dimension index: 15
# Latent dimension index: 16
# Latent dimension index: 17
# Latent dimension index: 18
# Latent dimension index: 19
# Latent dimension index: 20
# Latent dimension index: 21
# Latent dimension index: 22
# Latent dimension index: 23
# Latent dimension index: 24
# Latent dimension index: 25
# Latent dimension index: 26
# Latent dimension index: 27
# Latent dimension index: 28
# Latent dimension index: 29
# Latent dimension index: 30
# Latent dimension index: 31
# Latent dimension index: 32
# Latent dimension index: 33
# Latent dimension index: 34
# Latent dimension index: 35
# Latent dimension index: 36
# Latent dimension index: 37
# Latent dimension index: 38
# Latent dimension index: 39
# Latent dimension index: 40
# Latent dimension index: 41
# Latent dimension index: 42
# Latent dimension index: 43
# Latent dimension index: 44
# Latent dimension index: 45
# Latent dimension index: 46
# Latent dimension index: 47
# Latent dimension index: 48
# Latent dimension index: 49
# Latent dimension index: 50
# Latent dimension index: 51
# Latent dimension index: 52
# Latent dimension index: 53
# Latent dimension index: 54
# Latent dimension index: 55
# Latent dimension index: 56
# Latent dimension index: 57
# Latent dimension index: 58
# Latent dimension index: 59
# Latent dimension index: 60
# Latent dimension index: 61
# Latent dimension index: 62
# Latent dimension index: 63
# Latent dimension index: 64
# Latent dimension index: 65
# Latent dimension index: 66
# Latent dimension index: 67
# Latent dimension index: 68
# Latent dimension index: 69
# Latent dimension index: 70
# Latent dimension index: 71
# Latent dimension index: 72
# Latent dimension index: 73
# Latent dimension index: 74
# Latent dimension index: 75
# Latent dimension index: 76
# Latent dimension index: 77
# Latent dimension index: 78
# Latent dimension index: 79
# Latent dimension index: 80
# Latent dimension index: 81
# Latent dimension index: 82
# Latent dimension index: 83
# Latent dimension index: 84
# Latent dimension index: 85
# Latent dimension index: 86
# Latent dimension index: 87
# Latent dimension index: 88
# Latent dimension index: 89
# Latent dimension index: 90
# Latent dimension index: 91
# Latent dimension index: 92
# Latent dimension index: 93
# Latent dimension index: 94
# Latent dimension index: 95
# Latent dimension index: 96
# Latent dimension index: 97
# Latent dimension index: 98
# Latent dimension index: 99
# Latent dimension index: 100
# Latent dimension index: 101
# Latent dimension index: 102
# Latent dimension index: 103
# Latent dimension index: 104
# Latent dimension index: 105
# Latent dimension index: 106
# Latent dimension index: 107
# Latent dimension index: 108
# Latent dimension index: 109
# Latent dimension index: 110
# Latent dimension index: 111
# Latent dimension index: 112
# Latent dimension index: 113
# Latent dimension index: 114
# Latent dimension index: 115
# Latent dimension index: 116
# Latent dimension index: 117
# Latent dimension index: 118
# Latent dimension index: 119
# Latent dimension index: 120
# Latent dimension index: 121
# Latent dimension index: 122
# Latent dimension index: 123
# Latent dimension index: 124
# Latent dimension index: 125
# Latent dimension index: 126
# Latent dimension index: 127
# Latent dimension index: 128
# Latent dimension index: 129
# Latent dimension index: 130
# Latent dimension index: 131
# Latent dimension index: 132
# Latent dimension index: 133
# Latent dimension index: 134
# Latent dimension index: 135
# Latent dimension index: 136
# Latent dimension index: 137
# Latent dimension index: 138
# Latent dimension index: 139
# Latent dimension index: 140
# Latent dimension index: 141
# Latent dimension index: 142
# Latent dimension index: 143
# Latent dimension index: 144
# Latent dimension index: 145
# Latent dimension index: 146
# Latent dimension index: 147
# Latent dimension index: 148
# Latent dimension index: 149
# Latent dimension index: 150
# Latent dimension index: 151
# Latent dimension index: 152
# Latent dimension index: 153
# Latent dimension index: 154
# Latent dimension index: 155
# Latent dimension index: 156
# Latent dimension index: 157
# Latent dimension index: 158
# Latent dimension index: 159
# Latent dimension index: 160
# Latent dimension index: 161
# Latent dimension index: 162
# Latent dimension index: 163
# Latent dimension index: 164
# Latent dimension index: 165
# Latent dimension index: 166
# Latent dimension index: 167
# Latent dimension index: 168
# Latent dimension index: 169
# Latent dimension index: 170
# Latent dimension index: 171
# Latent dimension index: 172
# Latent dimension index: 173
# Latent dimension index: 174
# Latent dimension index: 175
# Latent dimension index: 176
# Latent dimension index: 177
# Latent dimension index: 178
# Latent dimension index: 179
# Latent dimension index: 180
# Latent dimension index: 181
# Latent dimension index: 182
# Latent dimension index: 183
# Latent dimension index: 184
# Latent dimension index: 185
# Latent dimension index: 186
# Latent dimension index: 187
# Latent dimension index: 188
# Latent dimension index: 189
# Latent dimension index: 190
# Latent dimension index: 191
# Latent dimension index: 192
# Latent dimension index: 193
# Latent dimension index: 194
# Latent dimension index: 195
# Latent dimension index: 196
# Latent dimension index: 197
# Latent dimension index: 198
# Latent dimension index: 199
# Latent dimension index: 200
# Latent dimension index: 201
# Latent dimension index: 202
# Latent dimension index: 203
# Latent dimension index: 204
# Latent dimension index: 205
# Latent dimension index: 206
# Latent dimension index: 207
# Latent dimension index: 208
# Latent dimension index: 209
# Latent dimension index: 210
# Latent dimension index: 211
# Latent dimension index: 212
# Latent dimension index: 213
# Latent dimension index: 214
# Latent dimension index: 215
# Latent dimension index: 216
# Latent dimension index: 217
# Latent dimension index: 218
# Latent dimension index: 219
# Latent dimension index: 220
# Latent dimension index: 221
# Latent dimension index: 222
# Latent dimension index: 223
# Latent dimension index: 224
# Latent dimension index: 225
# Latent dimension index: 226
# Latent dimension index: 227
# Latent dimension index: 228
# Latent dimension index: 229
# Latent dimension index: 230
# Latent dimension index: 231
# Latent dimension index: 232
# Latent dimension index: 233
# Latent dimension index: 234
# Latent dimension index: 235
# Latent dimension index: 236
# Latent dimension index: 237
# Latent dimension index: 238
# Latent dimension index: 239
# Latent dimension index: 240
# Latent dimension index: 241
# Latent dimension index: 242
# Latent dimension index: 243
# Latent dimension index: 244
# Latent dimension index: 245
# Latent dimension index: 246
# Latent dimension index: 247
# Latent dimension index: 248
# Latent dimension index: 249
# Latent dimension index: 250
# Latent dimension index: 251
# Latent dimension index: 252
# Latent dimension index: 253
# Latent dimension index: 254
# Latent dimension index: 255

# %%
a = np.linspace(-3, 3, 10)
b0, b1 = np.meshgrid(a, a)
latents = torch.zeros((100, ae_best.latent_dim))
for i in range(10):
    for j in range(10):
        latents[i*10+j,14] = b0[i,j]
        latents[i*10+j,56] = b1[i,j]
with torch.no_grad():
    generated_imgs = nn.Sigmoid()(ae_best.decoder(latents))
    imgviz(generated_imgs, save_fname='img.png')
